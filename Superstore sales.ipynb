# %%
import pandas as pd
import warnings
import numpy as np

warnings.filterwarnings('ignore',category=FutureWarning)

# %%
df = pd.read_csv(r"C:\Users\isaac\Downloads\train.csv")
df.head(7431)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 7426    7427  CA-2017-101693  25/06/2017  27/06/2017    Second Class
# 7427    7428  US-2015-164763  17/03/2015  21/03/2015  Standard Class
# 7428    7429  US-2015-164763  17/03/2015  21/03/2015  Standard Class
# 7429    7430  US-2015-164763  17/03/2015  21/03/2015  Standard Class
# 7430    7431  US-2015-164763  17/03/2015  21/03/2015  Standard Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# 0       CG-12520      Claire Gute   Consumer  United States        Henderson
# 1       CG-12520      Claire Gute   Consumer  United States        Henderson
# 2       DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...              ...        ...            ...              ...
# 7426    LC-17140     Logan Currie   Consumer  United States          Houston
# 7427    MH-17440    Mark Haberlin  Corporate  United States          Jackson
# 7428    MH-17440    Mark Haberlin  Corporate  United States          Jackson
# 7429    MH-17440    Mark Haberlin  Corporate  United States          Jackson
# 7430    MH-17440    Mark Haberlin  Corporate  United States          Jackson
#
#             State  Postal Code   Region       Product ID         Category  \
# 0        Kentucky      42420.0    South  FUR-BO-10001798        Furniture
# 1        Kentucky      42420.0    South  FUR-CH-10000454        Furniture
# 2      California      90036.0     West  OFF-LA-10000240  Office Supplies
# 3         Florida      33311.0    South  FUR-TA-10000577        Furniture
# 4         Florida      33311.0    South  OFF-ST-10000760  Office Supplies
# ...           ...          ...      ...              ...              ...
# 7426        Texas      77070.0  Central  FUR-FU-10003919        Furniture
# 7427  Mississippi      39212.0    South  OFF-BI-10000605  Office Supplies
# 7428  Mississippi      39212.0    South  OFF-BI-10000309  Office Supplies
# 7429  Mississippi      39212.0    South  OFF-PA-10003349  Office Supplies
# 7430  Mississippi      39212.0    South  OFF-PA-10003063  Office Supplies
#
#      Sub-Category                                       Product Name     Sales
# 0       Bookcases                  Bush Somerset Collection Bookcase  261.9600
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2          Labels  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3          Tables      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4         Storage                     Eldon Fold 'N Roll Cart System   22.3680
# ...           ...                                                ...       ...
# 7426  Furnishings  Eldon Executive Woodline II Cherry Finish Desk...   32.7120
# 7427      Binders  Acco Pressboard Covers with Storage Hooks, 9 1...   11.4300
# 7428      Binders  GBC Twin Loop Wire Binding Elements, 9/16" Spi...   30.4400
# 7429        Paper                                         Xerox 1957   12.9600
# 7430        Paper                               EcoTones Memo Sheets   16.0000
#
# [7431 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df['Postal Code'].unique()
# Out:
# array([42420., 90036., 33311., 90032., 28027., 98103., 76106., 53711.,
#        84084., 94109., 68025., 19140., 84057., 90049., 77095., 75080.,
#        77041., 60540., 32935., 55122., 48185., 19901., 47150., 10024.,
#        12180., 90004., 60610., 85234., 22153., 10009., 49201., 38109.,
#        77070., 35601., 94122., 27707., 60623., 29203., 55901., 55407.,
#        97206., 55106., 80013., 28205., 60462., 10035., 50322., 43229.,
#        37620., 19805., 61701., 85023., 95661., 64055., 91104., 43055.,
#        53132., 85254., 95123., 98105., 98115., 73034., 90045., 19134.,
#        88220., 78207., 77036., 62521., 71203.,  6824., 75051., 92374.,
#        45011.,  7090., 19120., 44312., 80219., 75220., 37064., 90604.,
#        48601., 44256., 43017., 48227., 38401., 33614., 95051., 55044.,
#        92037., 77506., 94513., 27514.,  7960., 45231., 94110., 90301.,
#        33319., 80906.,  7109., 48180.,  8701., 22204., 80004.,  7601.,
#        33710., 19143., 90805., 92345., 37130., 84041., 78745.,  1852.,
#        53214., 91911., 66502., 16602., 80229., 61821., 47401., 71854.,
#        78539., 77520., 46142., 90712.,  2895., 54880., 76021., 98042.,
#        74012., 33023., 33021., 77536., 67212., 78501., 52240., 83704.,
#         2920., 61032., 77642., 95610., 75056., 98052., 32114., 86442.,
#        46368., 58103., 46514., 91776., 33063., 30328., 44060., 73505.,
#        23666., 13440., 54601., 83501., 39401., 94526., 48858., 84321.,
#         6708., 30605.,  4240., 61832., 85323., 30062., 85364., 54401.,
#        99301., 60302., 32503., 77573., 20877., 84043., 35401., 92553.,
#        40324., 80538., 85224., 59601., 63122., 76706., 48066., 60423.,
#        18018., 55113., 68801., 55125., 48237., 72756., 88101., 33458.,
#        93101., 75104., 68701., 84020., 48104., 91941., 83201., 49423.,
#         6460., 60089., 92630., 96003., 95928., 13501., 72032., 82001.,
#        42301., 83605., 70065.,  3060., 38134., 94061., 37087., 93454.,
#        60016., 98632., 37075., 50701.,  2138., 60067.,  1915., 97405.,
#        93030., 98059., 60025., 33445., 80022., 77590., 27893., 87124.,
#        27534., 98208., 90640., 92020., 77705., 33407., 79605., 61761.,
#        63301., 60174., 93010., 97123., 91505., 95351., 67846.,  8401.,
#        80501., 95616., 26003., 95037.,  7011., 53081., 30344., 57701.,
#         1810., 34741.,  6484.,  6810., 52302., 32771., 78666., 80634.,
#        76063., 44035., 83301., 33134., 60441.,  1752., 20707., 77803.,
#        71603., 57401., 21740.,  7017., 60004., 60543., 55433., 92672.,
#        94568., 93405., 72762.])

# %%
df['Postal Code'].dtype
# Out:
# dtype('float64')

# %%
df.loc[df['Postal Code'].isna(),['Country','City','State']]
# Out:
#             Country        City    State
# 2234  United States  Burlington  Vermont
# 5274  United States  Burlington  Vermont
# 8798  United States  Burlington  Vermont
# 9146  United States  Burlington  Vermont
# 9147  United States  Burlington  Vermont
# 9148  United States  Burlington  Vermont
# 9386  United States  Burlington  Vermont
# 9387  United States  Burlington  Vermont
# 9388  United States  Burlington  Vermont
# 9389  United States  Burlington  Vermont
# 9741  United States  Burlington  Vermont

# %%
df.fillna(5401,inplace=True)

# %%
df['Postal Code'] = df['Postal Code'].astype(int)

# %%
import matplotlib.pyplot as plt

plt.hist(df['Sales'], bins=30, color='blue', edgecolor='black')
plt.title('Histogram of Sales')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9800 non-null   int32
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
#  17  Sales          9800 non-null   float64
# dtypes: float64(1), int32(1), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
df['Order Date'].unique()
# Out:
# array(['08/11/2017', '12/06/2017', '11/10/2016', ..., '18/06/2015',
#        '28/02/2018', '09/05/2016'], dtype=object)

# %%
df['Ship Date'].unique()
# Out:
# array(['11/11/2017', '16/06/2017', '18/10/2016', ..., '12/03/2015',
#        '06/04/2018', '13/05/2016'], dtype=object)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'],format='%d/%m/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format='%d/%m/%Y')
df.sample(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1929    1930  US-2018-101539 2018-03-16 2018-03-18    Second Class
# 163      164  CA-2017-113817 2017-11-07 2017-11-11  Standard Class
# 7833    7834  CA-2016-128958 2016-01-24 2016-01-28  Standard Class
# 854      855  CA-2017-123274 2017-02-19 2017-02-24  Standard Class
# 9113    9114  CA-2015-132010 2015-10-13 2015-10-15     First Class
# 8606    8607  CA-2018-162936 2018-08-18 2018-08-22  Standard Class
# 228      229  US-2016-145436 2016-02-28 2016-03-04  Standard Class
# 9323    9324  CA-2018-121853 2018-09-23 2018-09-29  Standard Class
# 7992    7993  CA-2017-133872 2017-06-14 2017-06-17     First Class
# 328      329  US-2017-141544 2017-08-30 2017-09-01     First Class
#
#      Customer ID      Customer Name      Segment        Country  \
# 1929    VM-21685    Valerie Mitchum  Home Office  United States
# 163     MJ-17740          Max Jones     Consumer  United States
# 7833    CR-12820        Cyra Reiten  Home Office  United States
# 854     GT-14710          Greg Tran     Consumer  United States
# 9113    MA-17995    Michelle Arnett  Home Office  United States
# 8606    CM-12160  Charles McCrossin     Consumer  United States
# 228     VD-21670  Valerie Dominguez     Consumer  United States
# 9323    DB-13660       Duane Benoit     Consumer  United States
# 7992    VM-21835      Vivian Mathis     Consumer  United States
# 328     PO-18850    Patrick O'Brill     Consumer  United States
#
#                  City          State  Postal Code Region       Product ID  \
# 1929          Seattle     Washington        98105   West  OFF-ST-10004180
# 163           Seattle     Washington        98115   West  OFF-BI-10004002
# 7833  West Palm Beach        Florida        33407  South  OFF-AR-10004757
# 854     New York City       New York        10035   East  OFF-ST-10000736
# 9113         Richmond       Virginia        23223  South  OFF-BI-10002432
# 8606      New Bedford  Massachusetts         2740   East  TEC-AC-10003614
# 228          Columbia      Tennessee        38401  South  FUR-CH-10004860
# 9323      Los Angeles     California        90036   West  OFF-PA-10003641
# 7992       Boca Raton        Florida        33433  South  TEC-AC-10000521
# 328      Philadelphia   Pennsylvania        19143   East  FUR-CH-10003312
#
#              Category Sub-Category  \
# 1929  Office Supplies      Storage
# 163   Office Supplies      Binders
# 7833  Office Supplies          Art
# 854   Office Supplies      Storage
# 9113  Office Supplies      Binders
# 8606       Technology  Accessories
# 228         Furniture       Chairs
# 9323  Office Supplies        Paper
# 7992       Technology  Accessories
# 328         Furniture       Chairs
#
#                                            Product Name    Sales
# 1929                          Safco Commercial Shelving   46.510
# 163     Wilson Jones International Size A4 Ring Binders   27.680
# 7833                            Crayola Colored Pencils   13.120
# 854   Carina Double Wide Media Storage Towers in Nat...  242.940
# 9113               Wilson Jones Standard D-Ring Binders   15.180
# 8606  Verbatim 25 GB 6x Blu-ray Single Layer Recorda...   23.180
# 228                        Global Low Back Tilter Chair  161.568
# 9323                                         Xerox 1909  211.040
# 7992    Verbatim Slim CD and DVD Storage Cases, 50/Pack   18.464
# 328   Hon 2090 “Pillow Soft” Series Mid Back Swivel/...  786.744

# %%
df['Order day'] = df['Order Date'].dt.day
df['Order month'] = df['Order Date'].dt.month
df['Order Year'] = df['Order Date'].dt.year

df['Ship day'] = df['Ship Date'].dt.day
df['Ship month'] = df['Ship Date'].dt.month
df['Ship Year'] = df['Ship Date'].dt.year
df.sample(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
#
rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Order day', 'Order month', 'Order Year',
#        'Ship day', 'Ship month', 'Ship Year'],
#       dtype='object')

# %%
new_df = df.drop(['Row ID', 'Order ID', 'Order Date', 'Ship Date','Customer ID', 'Customer Name','Country', 'City','Product ID', 'State'],axis='columns')

# %%
new_df.sample(10)
# Out:
#            Ship Mode      Segment  Postal Code   Region         Category  \
# 8281     First Class    Corporate        28540    South        Furniture
# 9650  Standard Class     Consumer        90045     West  Office Supplies
# 8100     First Class  Home Office        90045     West       Technology
# 6535  Standard Class     Consumer        14215     East        Furniture
# 8282    Second Class  Home Office        60174  Central       Technology
# 1928    Second Class  Home Office        98105     West  Office Supplies
# 7239  Standard Class     Consumer        95123     West  Office Supplies
# 2367     First Class     Consumer        20735     East  Office Supplies
# 1090  Standard Class    Corporate        28110    South       Technology
# 3819  Standard Class     Consumer        10024     East  Office Supplies
#
#      Sub-Category                                      Product Name     Sales  \
# 8281       Chairs             Harbour Creations Steel Folding Chair   207.000
# 9650          Art                                         Newell 31    37.170
# 8100     Machines                             Okidata MB760 Printer  3357.600
# 6535    Bookcases             DMI Eclipse Executive Suite Bookcases  4007.840
# 8282     Machines   Star Micronics TSP800 TSP847IIU Receipt Printer   600.530
# 1928        Paper                                         Xerox 214     6.480
# 7239    Envelopes                                   Staple envelope    39.760
# 2367        Paper    HP Office Recycled Paper (20Lb. and 87 Bright)    23.120
# 1090       Phones  Innergie mMini Combo Duo USB Travel Charging Kit    71.984
# 3819      Binders           Pressboard Data Binders by Wilson Jones    12.816
#
#       Order day  Order month  Order Year  Ship day  Ship month  Ship Year
# 8281          9            5        2018        10           5       2018
# 9650         26           11        2017        30          11       2017
# 8100         10            3        2017        13           3       2017
# 6535         17           11        2015        22          11       2015
# 8282         21           12        2016        26          12       2016
# 1928         16            3        2018        18           3       2018
# 7239         24           12        2017        30          12       2017
# 2367         10            2        2018        13           2       2018
# 1090          4            6        2018        10           6       2018
# 3819          9           10        2018        14          10       2018

# %%
new_df['Sales'] = np.log(new_df['Sales'])

# %%
label_encoders = ['Ship Mode','Segment','Region','Category','Sub-Category','Product Name','Sales']

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for cols in label_encoders:
    new_df[cols] = le.fit_transform(new_df[cols])
# Out:
# C:\Users\isaac\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9800 non-null   int32
#  1   Segment       9800 non-null   int32
#  2   Postal Code   9800 non-null   int32
#  3   Region        9800 non-null   int32
#  4   Category      9800 non-null   int32
#  5   Sub-Category  9800 non-null   int32
#  6   Product Name  9800 non-null   int32
#  7   Sales         9800 non-null   int64
#  8   Order day     9800 non-null   int32
#  9   Order month   9800 non-null   int32
#  10  Order Year    9800 non-null   int32
#  11  Ship day      9800 non-null   int32
#  12  Ship month    9800 non-null   int32
#  13  Ship Year     9800 non-null   int32
# dtypes: int32(13), int64(1)
# memory usage: 574.3 KB

# %%
x=new_df.drop('Sales',axis='columns')
y=new_df['Sales']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=10)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=1000)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000)

# %%
model.score(x_test,y_test)
# Out:
# 0.6740203055279489
